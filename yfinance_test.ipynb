# %%
import yfinance as yf

dat = yf.Ticker("MSFT")
dat.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices, and solutions worldwide. The Productivity and Business Processes segment offers Microsoft 365 commercial, enterprise mobility + security, windows commercial, power BI, exchange, sharepoint, Microsoft teams, security and compliance, and copilot; Microsoft 365 commercial products, such as Windows commercial on-premises and office licensed services; Microsoft 365 consumer products and cloud services, including Microsoft 365 consumer subscriptions, office licensed on-premises, and other consumer services; LinkedIn; dynamics products and cloud services, such as dynamics 365, cloud-based applications, and on-premises ERP and CRM applications. Its Intelligent Cloud segment provides Server products and cloud services comprising Azure and other cloud services, GitHub, Nuance Healthcare, virtual desktop offerings, and other cloud services; server products, including SQL and windows server, visual studio and system center related client access licenses, and other on-premises offerings; enterprise and partner services, such as enterprise support and nuance professional services, industry solutions, Microsoft partner network, and learning experience. The Personal Computing segment provides windows and devices, such as Windows OEM licensing and devices and surface and PC accessories; gaming services and solutions, such as Xbox hardware, content, and services, first- and third-party content Xbox game pass, subscriptions, and cloud gaming, advertising, and other cloud services; search and news advertising services that includes Bing and Copilot, Microsoft News and Edge, and third-party affiliates. It sells its products through OEMs, distributors, and resellers; and online and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 228000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 58,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2025,
#    'totalPay': 12251294,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 66,
#    'title': 'President & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2025,
#    'totalPay': 4532750,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 53,
#    'title': 'Executive VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2025,
#    'totalPay': 4444191,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Takeshi  Numoto',
#    'age': 54,
#    'title': 'Executive VP & Chief Marketing Officer',
#    'yearBorn': 1971,
#    'fiscalYear': 2025,
#    'totalPay': 2871250,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson B. Althoff',
#    'age': 52,
#    'title': 'Executive VP & CEO of Commercial Business',
#    'yearBorn': 1973,
#    'fiscalYear': 2025,
#    'totalPay': 4490115,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Carolina  Dybeck Happe',
#    'age': 53,
#    'title': 'Executive VP & COO',
#    'yearBorn': 1972,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 59,
#    'title': 'Corporate VP & Chief Accounting Officer',
#    'yearBorn': 1966,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Matthew  Kerner',
#    'title': 'CTO & Corporate VP of Worldwide Sales and Solutions',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Jonathan  Neilson',
#    'title': 'Vice President of Investor Relations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jonathan M. Palmer',
#    'title': 'Corporate Vice President & Chief Legal Officer',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 9,
#  'boardRisk': 8,
#  'compensationRisk': 5,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 5,
#  'governanceEpochDate': 1769904000,
#  'compensationAsOfEpochDate': 1767139200,
#  'irWebsite': 'http://www.microsoft.com/investor/default.aspx',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 393.67,
#  'open': 399.165,
#  'dayLow': 392.92,
#  'dayHigh': 401.79,
#  'regularMarketPreviousClose': 393.67,
#  'regularMarketOpen': 399.165,
#  'regularMarketDayLow': 392.92,
#  'regularMarketDayHigh': 401.79,
#  'dividendRate': 3.64,
#  'dividendYield': 0.91,
#  'exDividendDate': 1771459200,
#  'payoutRatio': 0.21280001,
#  'fiveYearAvgDividendYield': 0.79,
#  'beta': 1.084,
#  'trailingPE': 25.118347,
#  'forwardPE': 21.256594,
#  'volume': 52425974,
#  'regularMarketVolume': 52425974,
#  'averageVolume': 29683065,
#  'averageVolume10days': 55115180,
#  'averageDailyVolume10Day': 55115180,
#  'bid': 398.11,
#  'ask': 403.48,
#  'bidSize': 9,
#  'askSize': 4,
#  'marketCap': 2981424267264,
#  'fiftyTwoWeekLow': 344.79,
#  'fiftyTwoWeekHigh': 555.45,
#  'allTimeHigh': 555.45,
#  'allTimeLow': 0.088542,
#  'priceToSalesTrailing12Months': 9.760664,
#  'fiftyDayAverage': 468.8798,
#  'twoHundredDayAverage': 486.90326,
#  'trailingAnnualDividendRate': 3.48,
#  'trailingAnnualDividendYield': 0.008839891,
#  'currency': 'USD',
#  'tradeable': False,
#  'enterpriseValue': 3012532895744,
#  'profitMargins': 0.39044,
#  'floatShares': 7414713401,
#  'sharesOutstanding': 7425629076,
#  'sharesShort': 54651789,
#  'sharesShortPriorMonth': 66675893,
#  'sharesShortPreviousMonthDate': 1765756800,
#  'dateShortInterest': 1768435200,
#  'sharesPercentSharesOut': 0.0074,
#  'heldPercentInsiders': 0.00066,
#  'heldPercentInstitutions': 0.76041,
#  'shortRatio': 2.43,
#  'shortPercentOfFloat': 0.0074,
#  'impliedSharesOutstanding': 7432377656,
#  'bookValue': 52.615,
#  'priceToBook': 7.6240616,
#  'lastFiscalYearEnd': 1751241600,
#  'nextFiscalYearEnd': 1782777600,
#  'mostRecentQuarter': 1767139200,
#  'earningsQuarterlyGrowth': 0.595,
#  'netIncomeToCommon': 119262003200,
#  'trailingEps': 15.97,
#  'forwardEps': 18.87132,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 9.863,
#  'enterpriseToEbitda': 17.189,
#  '52WeekChange': -0.026878834,
#  'SandP52WeekChange': 0.14272952,
#  'lastDividendValue': 0.91,
#  'lastDividendDate': 1763596800,
#  'quoteType': 'EQUITY',
#  'currentPrice': 401.14,
#  'targetHighPrice': 730.0,
#  'targetLowPrice': 392.0,
#  'targetMeanPrice': 599.8636,
#  'targetMedianPrice': 600.0,
#  'recommendationMean': 1.23214,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 53,
#  'totalCash': 89461997568,
#  'totalCashPerShare': 12.048,
#  'ebitda': 175258992640,
#  'totalDebt': 123278000128,
#  'quickRatio': 1.239,
#  'currentRatio': 1.386,
#  'totalRevenue': 305453006848,
#  'debtToEquity': 31.539,
#  'revenuePerShare': 41.1,
#  'returnOnAssets': 0.1486,
#  'returnOnEquity': 0.34390998,
#  'grossProfits': 209498996736,
#  'freeCashflow': 53640626176,
#  'operatingCashflow': 160506003456,
#  'earningsGrowth': 0.598,
#  'revenueGrowth': 0.167,
#  'grossMargins': 0.68586,
#  'ebitdaMargins': 0.57377,
#  'operatingMargins': 0.47094002,
#  'financialCurrency': 'USD',
#  'symbol': 'MSFT',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Nasdaq Real Time Price',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'corporateActions': [],
#  'regularMarketChangePercent': 1.89753,
#  'regularMarketPrice': 401.14,
#  'postMarketTime': 1770425996,
#  'regularMarketTime': 1770411602,
#  'exchange': 'NMS',
#  'messageBoardId': 'finmb_21835',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EST',
#  'gmtOffSetMilliseconds': -18000000,
#  'market': 'us_market',
#  'esgPopulated': False,
#  'marketState': 'CLOSED',
#  'fullExchangeName': 'NasdaqGS',
#  'averageDailyVolume3Month': 29683065,
#  'fiftyTwoWeekLowChange': 56.350006,
#  'fiftyTwoWeekLowChangePercent': 0.16343282,
#  'fiftyTwoWeekRange': '344.79 - 555.45',
#  'fiftyTwoWeekHighChange': -154.31,
#  'fiftyTwoWeekHighChangePercent': -0.27781078,
#  'fiftyTwoWeekChangePercent': -2.6878834,
#  'dividendDate': 1773273600,
#  'earningsTimestamp': 1769634000,
#  'earningsTimestampStart': 1777496400,
#  'earningsTimestampEnd': 1777496400,
#  'earningsCallTimestampStart': 1769639400,
#  'earningsCallTimestampEnd': 1769639400,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 15.97,
#  'epsForward': 18.87132,
#  'epsCurrentYear': 16.73199,
#  'priceEpsCurrentYear': 23.974434,
#  'fiftyDayAverageChange': -67.73978,
#  'fiftyDayAverageChangePercent': -0.14447153,
#  'twoHundredDayAverageChange': -85.763245,
#  'twoHundredDayAverageChangePercent': -0.17614022,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 0,
#  'averageAnalystRating': '1.2 - Strong Buy',
#  'cryptoTradeable': False,
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'hasPrePostMarketData': True,
#  'firstTradeDateMilliseconds': 511108200000,
#  'postMarketChangePercent': 0.46367484,
#  'postMarketPrice': 403.0,
#  'postMarketChange': 1.8599854,
#  'regularMarketChange': 7.47,
#  'regularMarketDayRange': '392.92 - 401.79',
#  'displayName': 'Microsoft',
#  'trailingPegRatio': 1.5305}

# %%
import yfinance as yf
markets = ['US', 'GB', 'ASIA', 'EUROPE', 'RATES', 'COMMODITIES', 'CURRENCIES', 'CRYPTOCURRENCIES']

US = yf.Market('US')



status = US.status
status
summary = US.summary
summary
# Out:
# {'SNP': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'S&P 500',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': -1325583000000,
#   'priceHint': 2,
#   'regularMarketChange': -84.32031,
#   'regularMarketChangePercent': -1.2251016,
#   'regularMarketTime': 1770327875,
#   'regularMarketPrice': 6798.4,
#   'regularMarketPreviousClose': 6882.72,
#   'exchange': 'SNP',
#   'market': 'us_market',
#   'fullExchangeName': 'SNP',
#   'marketState': 'POST',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'gmtOffSetMilliseconds': -18000000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'symbol': '^GSPC'},
#  'DJI': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'Dow 30',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 694362600000,
#   'priceHint': 2,
#   'regularMarketChange': -592.58203,
#   'regularMarketChangePercent': -1.197104,
#   'regularMarketTime': 1770327880,
#   'regularMarketPrice': 48908.72,
#   'regularMarketPreviousClose': 49501.3,
#   'exchange': 'DJI',
#   'market': 'us_market',
#   'fullExchangeName': 'DJI',
#   'marketState': 'POST',
#   'sourceInterval': 120,
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'gmtOffSetMilliseconds': -18000000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'symbol': '^DJI'},
#  'NIM': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'Nasdaq',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 34612200000,
#   'priceHint': 2,
#   'regularMarketChange': -363.99414,
#   'regularMarketChangePercent': -1.5891762,
#   'regularMarketTime': 1770329759,
#   'regularMarketPrice': 22540.586,
#   'regularMarketPreviousClose': 22904.58,
#   'exchange': 'NIM',
#   'market': 'us_market',
#   'fullExchangeName': 'Nasdaq GIDS',
#   'marketState': 'POST',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'gmtOffSetMilliseconds': -18000000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'symbol': '^IXIC'},
#  'WCB': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'INDEX',
#   'typeDisp': 'Index',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'LOW',
#   'shortName': 'VIX',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 631290600000,
#   'priceHint': 2,
#   'regularMarketChange': 3.130001,
#   'regularMarketChangePercent': 16.791853,
#   'regularMarketTime': 1770326101,
#   'regularMarketPrice': 21.77,
#   'regularMarketPreviousClose': 18.64,
#   'exchange': 'WCB',
#   'market': 'us_market',
#   'fullExchangeName': 'Chicago Options',
#   'marketState': 'POST',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 15,
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'gmtOffSetMilliseconds': -18000000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'symbol': '^VIX'},
#  'CMX': {'language': 'en-US',
#   'region': 'US',
#   'quoteType': 'FUTURE',
#   'typeDisp': 'Futures',
#   'quoteSourceName': 'Delayed Quote',
#   'triggerable': False,
#   'customPriceAlertConfidence': 'NONE',
#   'contractSymbol': False,
#   'headSymbolAsString': 'GC=F',
#   'shortName': 'Gold',
#   'hasPrePostMarketData': False,
#   'firstTradeDateMilliseconds': 967608000000,
#   'regularMarketChange': -100.799805,
#   'regularMarketChangePercent': -2.0615566,
#   'regularMarketTime': 1770332652,
#   'regularMarketPrice': 4788.7,
#   'regularMarketPreviousClose': 4889.5,
#   'exchange': 'CMX',
#   'market': 'us24_market',
#   'fullExchangeName': 'COMEX',
#   'marketState': 'REGULAR',
#   'sourceInterval': 15,
#   'exchangeDataDelayedBy': 10,
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'gmtOffSetMilliseconds': -18000000,
#   'esgPopulated': False,
#   'tradeable': False,
#   'cryptoTradeable': False,
#   'symbol': 'GC=F'}}

# %%
import yfinance as yf

tech = yf.Sector('technology')
software = yf.Industry('software-infrastructure')

# Common information
tech.key
tech.name
tech.symbol
tech.ticker
tech.overview
tech.top_companies
tech.research_reports

# Sector information
tech.top_etfs
tech.top_mutual_funds
tech.industries

# Industry information
software.sector_key
software.sector_name
software.top_performing_companies
software.top_growth_companies
# Out:
#                     name  ytd return  growth estimate
# symbol
# CFLT     Confluent, Inc.      0.0040         5.500000
# OSPN        OneSpan Inc.     -0.1674         2.000000
# IOT         Samsara Inc.     -0.3159         1.428571
# GTLB         GitLab Inc.     -0.1844         1.350000
# CTLP    Cantaloupe, Inc.      0.0047         1.133333

# %%
tech.top_companies
# Out:
#                                                name      rating  market weight
# symbol
# NVDA                             NVIDIA Corporation  Strong Buy       0.195251
# AAPL                                     Apple Inc.         Buy       0.189020
# MSFT                          Microsoft Corporation  Strong Buy       0.136402
# AVGO                                  Broadcom Inc.  Strong Buy       0.068621
# MU                          Micron Technology, Inc.         Buy       0.020079
# ORCL                             Oracle Corporation         Buy       0.018268
# CSCO                            Cisco Systems, Inc.         Buy       0.015168
# AMD                    Advanced Micro Devices, Inc.         Buy       0.014605
# PLTR                     Palantir Technologies Inc.         Buy       0.014440
# IBM     International Business Machines Corporation         Buy       0.012630
# LRCX                       Lam Research Corporation         Buy       0.012488
# AMAT                        Applied Materials, Inc.         Buy       0.011246
# INTC                              Intel Corporation        Hold       0.011232
# TXN                  Texas Instruments Incorporated        Hold       0.009486
# CRM                                Salesforce, Inc.         Buy       0.008430
# KLAC                                KLA Corporation         Buy       0.008152
# ANET                          Arista Networks, Inc.  Strong Buy       0.007552
# ADI                            Analog Devices, Inc.         Buy       0.007352
# UBER                        Uber Technologies, Inc.         Buy       0.007311
# APH                            Amphenol Corporation         Buy       0.007282
# QCOM                          QUALCOMM Incorporated         Buy       0.006804
# SHOP                                   Shopify Inc.         Buy       0.006767
# ACN                                   Accenture plc         Buy       0.006752
# INTU                                    Intuit Inc.         Buy       0.005644
# ADBE                                     Adobe Inc.         Buy       0.005256
# NOW                                ServiceNow, Inc.  Strong Buy       0.005047
# PANW                       Palo Alto Networks, Inc.         Buy       0.005027
# GLW                            Corning Incorporated  Strong Buy       0.004507
# CRWD                     CrowdStrike Holdings, Inc.         Buy       0.004435
# ADP                 Automatic Data Processing, Inc.        Hold       0.004411
# WDC                     Western Digital Corporation         Buy       0.004146
# STX                 Seagate Technology Holdings plc         Buy       0.004121
# SNDK                            Sandisk Corporation         Buy       0.003961
# SNPS                                 Synopsys, Inc.         Buy       0.003660
# DELL                         Dell Technologies Inc.         Buy       0.003605
# CDNS                   Cadence Design Systems, Inc.         Buy       0.003431
# MSI                        Motorola Solutions, Inc.         Buy       0.003239
# MRVL                       Marvell Technology, Inc.         Buy       0.002982
# TEL                             TE Connectivity plc         Buy       0.002855
# FTNT                                 Fortinet, Inc.        Hold       0.002819
# NET                                Cloudflare, Inc.         Buy       0.002662
# NXPI                        NXP Semiconductors N.V.         Buy       0.002610
# MPWR                 Monolithic Power Systems, Inc.  Strong Buy       0.002581
# SNOW                                 Snowflake Inc.         Buy       0.002500
# ADSK                                 Autodesk, Inc.  Strong Buy       0.002363
# TER                                  Teradyne, Inc.         Buy       0.002010
# WDAY                                  Workday, Inc.         Buy       0.001976
# MCHP              Microchip Technology Incorporated         Buy       0.001966
# CRWV                                CoreWeave, Inc.         Buy       0.001814
# GRMN                                    Garmin Ltd.        Hold       0.001783
